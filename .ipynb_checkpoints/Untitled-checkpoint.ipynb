# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("C:/Users/AMISHA/Desktop/Minor Project/StudentsPerformance.csv")

# %% [markdown]
# # Understanding the data

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
data.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
data['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
data.shape
# Out:
# (1000, 8)

# %%
data.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
data.nunique()
# Out:
# gender                          2
# race/ethnicity                  5
# parental level of education     6
# lunch                           2
# test preparation course         2
# math score                     81
# reading score                  72
# writing score                  77
# dtype: int64

# %%
data['total'] = data['math score'] + data['reading score']+data['writing score']

# %%
data['average'] = data['total']/3

# %% [markdown]
# # Cleaning the data

# %%
data.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
data.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
student = data.drop(['race/ethnicity','parental level of education'],axis=1)

# %%
student.head()
# Out:
#    gender         lunch test preparation course  math score  reading score  \
# 0  female      standard                    none          72             72
# 1  female      standard               completed          69             90
# 2  female      standard                    none          90             95
# 3    male  free/reduced                    none          47             57
# 4    male      standard                    none          76             78
#
#    writing score
# 0             74
# 1             88
# 2             93
# 3             44
# 4             75

# %% [markdown]
# # Relationship Analysis

# %%
sns.distplot(student['math score'],bins=5)

# %%
sns.catplot(x='math score', kind='box', data=student)

# %%
sns.distplot(student['reading score'],bins=5)

# %%
sns.catplot(x='reading score', kind='box', data=student)

# %%
sns.distplot(student['writing score'],bins=5)

# %%
sns.catplot(x='writing score', kind='box', data=student)

# %%
sns.distplot(data['average'])

# %%
corelation = student.corr()

# %%
sns.heatmap(corelation , xticklabels = corelation.columns, yticklabels = corelation.columns, annot=True)

# %%
sns.pairplot(student)

# %%
#ANALYSIS : If a student is securing high marks in a subject, there are high chances of student scoring greater marks in some other subject as well

# %%
sns.relplot(x= 'reading score', y = 'math score', hue='gender', data=student)

# %%
sns.relplot(x= 'reading score', y = 'math score', hue='lunch', data=student)

# %%
sns.barplot(student['gender'],data['average'])

# %%
sns.barplot(student['lunch'],data['average'])

# %%
sns.barplot(student['test preparation course'],data['average'])

# %%
student['math_passStat'] = np.where(student['math score']<40, 'F' ,'P')

# %%
student['read_passStat'] = np.where(student['reading score']<40, 'F' ,'P')

# %%
student['write_passStat'] = np.where(student['writing score']<40, 'F' ,'P')

# %%
student['math_passStat'].value_counts()
# Out:
# P    960
# F     40
# Name: math_passStat, dtype: int64

# %%
student['read_passStat'].value_counts()
# Out:
# P    974
# F     26
# Name: read_passStat, dtype: int64

# %%
student['write_passStat'].value_counts()
# Out:
# P    968
# F     32
# Name: write_passStat, dtype: int64

# %%
p = sns.countplot(x='lunch', data=student, hue='math_passStat', palette='bright')
_ = plt.setp(p.get_xticklabels(), rotation=90)

# %%
p = sns.countplot(x='gender', data=student, hue='math_passStat', palette='bright')
_ = plt.setp(p.get_xticklabels(), rotation=90)

# %%
p = sns.countplot(x='test preparation course', data=student, hue='math_passStat', palette='bright')
_ = plt.setp(p.get_xticklabels(), rotation=90)

# %%
p = sns.countplot(x='lunch', data=student, hue='write_passStat', palette='bright')
_ = plt.setp(p.get_xticklabels(), rotation=90)

# %%
p = sns.countplot(x='gender', data=student, hue='write_passStat', palette='bright')
_ = plt.setp(p.get_xticklabels(), rotation=90)

# %%
p = sns.countplot(x='test preparation course', data=student, hue='write_passStat', palette='bright')
_ = plt.setp(p.get_xticklabels(), rotation=90)

# %%
p = sns.countplot(x='lunch', data=student, hue='read_passStat', palette='bright')
_ = plt.setp(p.get_xticklabels(), rotation=90)

# %%
p = sns.countplot(x='gender', data=student, hue='read_passStat', palette='bright')
_ = plt.setp(p.get_xticklabels(), rotation=90)

# %%
p = sns.countplot(x='test preparation course', data=student, hue='write_passStat', palette='bright')
_ = plt.setp(p.get_xticklabels(), rotation=90)
